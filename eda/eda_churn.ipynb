# %%
import pandas as pd

# %% [markdown]
# # Criar DataFrames com base nos Datasets

# %%
# Carregar Dataframe de Clientes (Customers)
df_customers = pd.read_csv('./datasets/churn_customers.csv')

# %%
# Mostrar 5 primeiros registros do DataFrame
df_customers.head()

# %%
# Mostrar 5 últimos registros do DataFrame
df_customers.tail()

# %%
# Mostrar estrutura / schema do DataFrame
df_customers.info()

# %%
# Carregar DataFrame de Serviços (Services)
df_services = pd.read_csv('./datasets/churn_services.csv')

# %%
# Mostrar 5 primeiras linhas do DataFrame
df_services.head(5)

# %%
# Mostrar 5 últimos registros do DataFrame
df_services.tail(5)

# %%
# Mostrar estrutura / schema do DataFrame
df_services.info()

# %%
# Carregar DataFrame de Contratos (Contracts)
df_contracts = pd.read_csv('./datasets/churn_contracts.csv')

# %%
# Mostrar 5 primeiras linhas do DataFrame
df_contracts.head(5)

# %%
# Mostrar 5 últimos registros do DataFrame
df_contracts.tail(5)

# %%
# Mostrar estrutura / schema do DataFrame
df_contracts.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   str
#  3   PaperlessBilling  7043 non-null   str
#  4   PaymentMethod     7043 non-null   str
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   str
#  7   Churn             7043 non-null   str
# dtypes: float64(1), int64(1), str(6)
# memory usage: 440.3 KB

# %% [markdown]
# ## Transformação de Dados

# %%
# Transformar coluna 'TotalCharges' de str para float - astype
df_contracts['TotalCharges'] = df_contracts['TotalCharges'].astype(float)

# %%
# Transformar coluna 'TotalCharges' de str para float - to_numeric
df_contracts['TotalCharges'] = pd.to_numeric(df_contracts['TotalCharges'], errors='coerce')

# %%
# Mostrar estrutura / schema do Dataframe
df_contracts.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   tenure            7043 non-null   int64
#  2   Contract          7043 non-null   str
#  3   PaperlessBilling  7043 non-null   str
#  4   PaymentMethod     7043 non-null   str
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7032 non-null   float64
#  7   Churn             7043 non-null   str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 440.3 KB

# %% [markdown]
# Após transformação da coluna TotalCharges do Dataframe Contracts, a coluna passou a ter 11 valores ausentes (missing values)

# %% [markdown]
# ## Renomear Colunas

# %%
df_customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   str
#  1   gender         7043 non-null   str
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   str
#  4   Dependents     7043 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 275.2 KB

# %%
# Renomear coluna no DataFrame, usando rename e dict
df_customers.rename(columns={'SeniorCitizen': 'Above65yo'}, inplace=True)

# %%
df_customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  7043 non-null   str
#  1   gender      7043 non-null   str
#  2   Above65yo   7043 non-null   int64
#  3   Partner     7043 non-null   str
#  4   Dependents  7043 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 275.2 KB

# %%
# Renomear usando lista - modificar todos os nomes e colunas
df_customers.columns = ['IDCliente', 'Genero', 'Mais65anos', 'TemParceiro', 'TemDependentes']

# %%
# Mostrar estrutura / schema do DataFrame após renomear colunas
df_customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   IDCliente       7043 non-null   str
#  1   Genero          7043 non-null   str
#  2   Mais65anos      7043 non-null   int64
#  3   TemParceiro     7043 non-null   str
#  4   TemDependentes  7043 non-null   str
# dtypes: int64(1), str(4)
# memory usage: 275.2 KB
